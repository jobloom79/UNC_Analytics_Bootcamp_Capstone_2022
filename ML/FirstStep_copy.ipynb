# %% [markdown]
# <a href="https://colab.research.google.com/github/jobloom79/UNC_Analytics_Bootcamp_Capstone_2022/blob/customer_acceptance_test/FirstStep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import io
import pandas as pd
import os

data = r'/Users/dang/Documents/Bootcamp/UNC_Analytics_Bootcamp_Capstone_2022/Data/preliminary_data'
data_1 = r'/Users/dang/Documents/Bootcamp/UNC_Analytics_Bootcamp_Capstone_2022/ML'

# %%
df = pd.read_csv(os.path.join(data,'austin-animal-center-intakes-1.csv'))

# %%
df.head()
# Out:
#   Animal ID     Name                DateTime               MonthYear  \
# 0   A803421      NaN  09/01/2019 12:36:00 AM  09/01/2019 12:36:00 AM
# 1   A803419      NaN  08/31/2019 07:07:00 PM  08/31/2019 07:07:00 PM
# 2   A800462    Spots  08/31/2019 07:00:00 PM  08/31/2019 07:00:00 PM
# 3   A800463  Delilah  08/31/2019 07:00:00 PM  08/31/2019 07:00:00 PM
# 4   A803416      NaN  08/31/2019 06:36:00 PM  08/31/2019 06:36:00 PM
#
#                                       Found Location Intake Type  \
# 0                      800 Dawlish Dr in Travis (TX)       Stray
# 1  East Slaughter And Pleasant Valley in Austin (TX)       Stray
# 2                   102 W Powell Lane in Austin (TX)       Stray
# 3                   102 W Powell Lane in Austin (TX)       Stray
# 4                   610 Thrasher Lane in Austin (TX)       Stray
#
#   Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0           Normal         Dog         Unknown          1 year
# ...

# %%
df_2 = pd.read_csv(os.path.join(data,'austin-animal-center-outcomes-1.csv'))
df_2.head()
# Out:
#   Animal ID      Name                DateTime               MonthYear  \
# 0   A771830  *Bradley  12/27/2018 01:25:00 PM  12/27/2018 01:25:00 PM
# 1   A779576    *Rajah  10/01/2018 05:03:00 PM  10/01/2018 05:03:00 PM
# 2   A741715  *Pebbles  01/11/2017 06:17:00 PM  01/11/2017 06:17:00 PM
# 3   A658751     Benji  11/13/2016 01:38:00 PM  11/13/2016 01:38:00 PM
# 4   A721285       NaN  02/24/2016 02:42:00 PM  02/24/2016 02:42:00 PM
#
#   Date of Birth     Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# 0    05/10/2017         Adoption          Foster         Dog    Neutered Male
# 1    04/18/2018         Adoption             NaN         Cat    Neutered Male
# 2    03/07/2016         Adoption             NaN         Cat    Spayed Female
# 3    07/14/2011  Return to Owner             NaN         Dog    Neutered Male
# 4    02/24/2014       Euthanasia       Suffering       Other          Unknown
#
#   Age upon Outcome                   Breed        Color
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107289 entries, 0 to 107288
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Animal ID         107289 non-null  object
#  1   Name              73334 non-null   object
#  2   DateTime          107289 non-null  object
#  3   MonthYear         107289 non-null  object
#  4   Found Location    107289 non-null  object
#  5   Intake Type       107289 non-null  object
#  6   Intake Condition  107289 non-null  object
#  7   Animal Type       107289 non-null  object
#  8   Sex upon Intake   107288 non-null  object
#  9   Age upon Intake   107289 non-null  object
#  10  Breed             107289 non-null  object
#  11  Color             107289 non-null  object
# dtypes: object(12)
# memory usage: 9.8+ MB

# %%
df = pd.read_csv(os.path.join(data,'Public_Use_Ixodes_County_Table_2022.csv'))
df.head()
# Out:
#    FIPSCode State                                             County  \
# 0      1001  AL    Autauga County                                ...
# 1      1003  AL    Baldwin County                                ...
# 2      1005  AL    Barbour County                                ...
# 3      1007  AL    Bibb County                                   ...
# 4      1009  AL    Blount County                                 ...
#
#   Ixodes_scapularis_County_Status          Ixodes_scapularis_data_source  \
# 0                     Established  CDC ArboNET Tick Module historic data
# 1                     Established  CDC ArboNET Tick Module historic data
# 2                     Established  CDC ArboNET Tick Module historic data
# 3                     Established  CDC ArboNET Tick Module historic data
# 4                      No records  CDC ArboNET Tick Module historic data
#
#   Ixodes_pacificus_county_status           Ixodes_pacificus_data_source
# ...

# %%
df = pd.read_csv(os.path.join(data,'Public_Use_Ixodes_Pathogens_County_Table_2022.csv'))
df.head()
# Out:
#    FIPS_Code State                                             County  \
# 0       1001  AL    Autauga County                                ...
# 1       1003  AL    Baldwin County                                ...
# 2       1005  AL    Barbour County                                ...
# 3       1007  AL    Bibb County                                   ...
# 4       1009  AL    Blount County                                 ...
#
#   Borrelia_burgdorferi_sensu_stricto_County_Status  \
# 0                                       No Records
# 1                                       No Records
# 2                                       No Records
# 3                                       No Records
# 4                                       No Records
#
#   Borrelia_burgdorferi_sensu_stricto_Data_Source  \
# 0          CDC ArboNET Tick Module historic data
# 1          CDC ArboNET Tick Module historic data
# 2          CDC ArboNET Tick Module historic data
# ...

# %%
df = pd.read_csv(os.path.join(data,'tick_2019.csv'))
df.head()
# Out:
#    FIPSCode State          County Ixodes_scapularis_County_Status  \
# 0      1001    AL  Autauga County                     Established
# 1      1003    AL  Baldwin County                     Established
# 2      1005    AL  Barbour County                     Established
# 3      1007    AL     Bibb County                     Established
# 4      1009    AL   Blount County                      No records
#
#            Ixodes_scapularis_data_source Ixodes_pacificus_county_status  \
# 0  CDC ArboNET Tick Module historic data                     No records
# 1  CDC ArboNET Tick Module historic data                     No records
# 2  CDC ArboNET Tick Module historic data                     No records
# 3  CDC ArboNET Tick Module historic data                     No records
# 4  CDC ArboNET Tick Module historic data                     No records
#
#               Ixodes_pacificus_data_source
# 0  CDC ArboNET Tick Module historical data
# 1  CDC ArboNET Tick Module historical data
# ...

# %%
df_1 = pd.read_csv(os.path.join(data_1,'Animal_Data.csv'))
df_1.head()
# Out:
#   Animal_ID     Name State       Age            Sex Animal_type Breed_Class  \
# 0   A803419      NaN    TX   2 years    Intact Male         Dog       Small
# 1   A800463  Delilah    TX  7 months  Intact Female         Dog      Medium
# 2   A803414   Martie    TX   2 years  Intact Female         Dog       Large
# 3   A803417      NaN    TX   1 month  Intact Female         Dog      Medium
# 4   A803412      NaN    TX  5 months    Intact Male         Dog       Small
#
#             Color  Weight_lbs  Temperature  ...  Vomiting Diarrhea  \
# 0     Black/White           7          NaN  ...      None     None
# 1       Tan/Black          45          NaN  ...      Mild     Mild
# 2  Black/Tricolor          63          NaN  ...      Mild     None
# 3       Brown/Tan          39          NaN  ...      Mild     Mild
# 4     Brown/Black          21          NaN  ...      None     None
#
#   Inappetence Lethargic Lameness Muscle_pain Joint_swelling  \
# ...

# %%
df_1.set_index('Animal_ID', inplace=True)
df_1.head()
# Out:
#               Name State       Age            Sex Animal_type Breed_Class  \
# Animal_ID
# A803419        NaN    TX   2 years    Intact Male         Dog       Small
# A800463    Delilah    TX  7 months  Intact Female         Dog      Medium
# A803414     Martie    TX   2 years  Intact Female         Dog       Large
# A803417        NaN    TX   1 month  Intact Female         Dog      Medium
# A803412        NaN    TX  5 months    Intact Male         Dog       Small
#
#                     Color  Weight_lbs  Temperature  Heart_Rate_bpm  ...  \
# Animal_ID                                                           ...
# A803419       Black/White           7          NaN             146  ...
# A800463         Tan/Black          45          NaN             116  ...
# A803414    Black/Tricolor          63          NaN             161  ...
# A803417         Brown/Tan          39          NaN             129  ...
# A803412       Brown/Black          21          NaN             165  ...
#
# ...

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49509 entries, A803419 to A521520
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name                  41539 non-null  object
#  1   State                 49509 non-null  object
#  2   Age                   49509 non-null  object
#  3   Sex                   49508 non-null  object
#  4   Animal_type           49509 non-null  object
#  5   Breed_Class           49509 non-null  object
#  6   Color                 49509 non-null  object
#  7   Weight_lbs            49509 non-null  int64
#  8   Temperature           0 non-null      float64
#  9   Heart_Rate_bpm        49509 non-null  int64
#  10  Resp_Rate_bpm         49509 non-null  object
#  11  MM                    49509 non-null  object
#  12  CRT                   49509 non-null  object
#  13  Mentation             49509 non-null  object
#  14  Vomiting              49509 non-null  object
# ...

# %%
df_2.set_index("Animal ID", inplace=True)
df_2.head()
# Out:
#                Name                DateTime               MonthYear  \
# Animal ID
# A771830    *Bradley  12/27/2018 01:25:00 PM  12/27/2018 01:25:00 PM
# A779576      *Rajah  10/01/2018 05:03:00 PM  10/01/2018 05:03:00 PM
# A741715    *Pebbles  01/11/2017 06:17:00 PM  01/11/2017 06:17:00 PM
# A658751       Benji  11/13/2016 01:38:00 PM  11/13/2016 01:38:00 PM
# A721285         NaN  02/24/2016 02:42:00 PM  02/24/2016 02:42:00 PM
#
#           Date of Birth     Outcome Type Outcome Subtype Animal Type  \
# Animal ID
# A771830      05/10/2017         Adoption          Foster         Dog
# A779576      04/18/2018         Adoption             NaN         Cat
# A741715      03/07/2016         Adoption             NaN         Cat
# A658751      07/14/2011  Return to Owner             NaN         Dog
# A721285      02/24/2014       Euthanasia       Suffering       Other
#
#           Sex upon Outcome Age upon Outcome                   Breed  \
# Animal ID
# ...

# %%
new_df = pd.merge(df_1, df_2, left_index=True, right_index=True)
new_df.head()
# Out:
#         Name_x State       Age            Sex Animal_type Breed_Class  \
# A006100  Scamp    TX  10 years  Neutered Male         Dog       Small
# A006100  Scamp    TX  10 years  Neutered Male         Dog       Small
# A006100  Scamp    TX  10 years  Neutered Male         Dog       Small
# A006100  Scamp    TX   7 years  Neutered Male         Dog       Large
# A006100  Scamp    TX   7 years  Neutered Male         Dog       Large
#
#               Color_x  Weight_lbs  Temperature  Heart_Rate_bpm  ...  \
# A006100  Yellow/White          23          NaN             160  ...
# A006100  Yellow/White          23          NaN             160  ...
# A006100  Yellow/White          23          NaN             160  ...
# A006100  Yellow/White          75          NaN             108  ...
# A006100  Yellow/White          75          NaN             108  ...
#
#                        DateTime               MonthYear Date of Birth  \
# ...

# %%
animal_data_1_df = pd.merge(df_1, df_2, right_index=True, left_index=True)
animal_data_1_df
# Out:
#          Name_x State        Age            Sex Animal_type Breed_Class  \
# A006100   Scamp    TX   10 years  Neutered Male         Dog       Small
# A006100   Scamp    TX   10 years  Neutered Male         Dog       Small
# A006100   Scamp    TX   10 years  Neutered Male         Dog       Small
# A006100   Scamp    TX    7 years  Neutered Male         Dog       Large
# A006100   Scamp    TX    7 years  Neutered Male         Dog       Large
# ...         ...   ...        ...            ...         ...         ...
# A788566     NaN    TX    5 weeks    Intact Male         Dog       Large
# A788578    Taco    TX     1 year    Intact Male         Dog       Large
# A788593    Isco    TX  10 months    Intact Male         Dog       Small
# A788677  Baxter    TX     1 year  Neutered Male         Dog       Small
# A788699     NaN    TX    5 years  Intact Female         Dog      Medium
#
#               Color_x  Weight_lbs  Temperature  Heart_Rate_bpm  ...  \
# ...

# %%
animal_data_1_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 65982 entries, A006100 to A788699
# Data columns (total 35 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name_x                58597 non-null  object
#  1   State                 65982 non-null  object
#  2   Age                   65982 non-null  object
#  3   Sex                   65981 non-null  object
#  4   Animal_type           65982 non-null  object
#  5   Breed_Class           65982 non-null  object
#  6   Color_x               65982 non-null  object
#  7   Weight_lbs            65982 non-null  int64
#  8   Temperature           0 non-null      float64
#  9   Heart_Rate_bpm        65982 non-null  int64
#  10  Resp_Rate_bpm         65982 non-null  object
#  11  MM                    65982 non-null  object
#  12  CRT                   65982 non-null  object
#  13  Mentation             65982 non-null  object
#  14  Vomiting              65982 non-null  object
# ...
